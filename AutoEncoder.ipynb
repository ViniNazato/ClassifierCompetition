# %% [markdown]
# # AutoEncoder

# %% [markdown]
# ### Imports

# %%
from NeuralModels.AutoEncoder import AutoEncoder, AutoEncoderOptimization
from utils.DataManager import DataManager
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report, roc_auc_score, RocCurveDisplay

# %% [markdown]
# #### Lê os dados usando classe própria `DataManager` -> Uso bem simples

# %%
data_manager = DataManager(r'..\data\Train.xlsx')

# %%
df = data_manager.get_original_df()

proporcao_classes = df['Class'].value_counts(normalize=True) * 100

print('Proporção das classes:', proporcao_classes)
# Out:
# Class
# 0    99.785059
# 1     0.214941
# Name: proportion, dtype: float64
# Proporção das classes: Class
# 0    99.785059
# 1     0.214941
# Name: proportion, dtype: float64

# %%
X_train, X_test, y_train, y_test = data_manager.train_test_splits(0.7)

y_train.value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.785145
# 1     0.214855
# Name: proportion, dtype: float64

# %%
autoencoder = AutoEncoder()
optimizator = AutoEncoderOptimization(X_train,y_train, model=autoencoder, lr=0.0001)
train_losses = optimizator.fit(epochs=100)
# Out:
# Epoch [1/100], loss:0.2671823871067696
# Epoch [2/100], loss:0.187743515508224
# Epoch [3/100], loss:0.16880727234596402
# Epoch [4/100], loss:0.15061688079969685
# Epoch [5/100], loss:0.1402962110167322
# Epoch [6/100], loss:0.1352276852307232
# Epoch [7/100], loss:0.1312414309771453
# Epoch [8/100], loss:0.12733722111532159
# Epoch [9/100], loss:0.12418289104984094
# Epoch [10/100], loss:0.12178716823487702
# Epoch [11/100], loss:0.11970298214523434
# Epoch [12/100], loss:0.11777382352198361
# Epoch [13/100], loss:0.115983702822993
# Epoch [14/100], loss:0.11445054375599462
# Epoch [15/100], loss:0.11309477679727968
# Epoch [16/100], loss:0.11177853519247828
# Epoch [17/100], loss:0.1105326329099495
# Epoch [18/100], loss:0.10944106198397315
# Epoch [19/100], loss:0.10848048276268205
# Epoch [20/100], loss:0.10763117240629354
# Epoch [21/100], loss:0.10684331474867731
# Epoch [22/100], loss:0.1061817893813886
# Epoch [23/100], loss:0.10547252495185001
# Epoch [24/100], loss:0.1048488705643216
# Epoch [25/100], loss:0.104275868785164
# Epoch [26/100], loss:0.10373388251848052
# Epoch [27/100], loss:0.10320427696120264
# Epoch [28/100], loss:0.1027068830860663
# Epoch [29/100], loss:0.10223210682419061
# Epoch [30/100], loss:0.10180334088042889
# Epoch [31/100], loss:0.10140707705770234
# Epoch [32/100], loss:0.10096483266215918
# Epoch [33/100], loss:0.10054744743256558
# Epoch [34/100], loss:0.10017874702861009
# Epoch [35/100], loss:0.09984310669733759
# Epoch [36/100], loss:0.09949006323023257
# Epoch [37/100], loss:0.09916771494625605
# Epoch [38/100], loss:0.09885315677929217
# Epoch [39/100], loss:0.09852966140036028
# Epoch [40/100], loss:0.09822969558948665
# Epoch [41/100], loss:0.09791825905612277
# Epoch [42/100], loss:0.09763388493612321
# Epoch [43/100], loss:0.0973423769443008
# Epoch [44/100], loss:0.09705924718945828
# Epoch [45/100], loss:0.0968122331981801
# Epoch [46/100], loss:0.0965612337310484
# Epoch [47/100], loss:0.09631690509864091
# Epoch [48/100], loss:0.09607169298559319
# Epoch [49/100], loss:0.09583021145062032
# Epoch [50/100], loss:0.09558533925553765
# Epoch [51/100], loss:0.09536271702188188
# Epoch [52/100], loss:0.09512187816428667
# Epoch [53/100], loss:0.09490752337314344
# Epoch [54/100], loss:0.09468146375202383
# Epoch [55/100], loss:0.0943971609143603
# Epoch [56/100], loss:0.09417599772750883
# Epoch [57/100], loss:0.093930641344222
# Epoch [58/100], loss:0.09367299574457634
# Epoch [59/100], loss:0.09342730983224978
# Epoch [60/100], loss:0.09322048562368641
# Epoch [61/100], loss:0.09298492203946901
# Epoch [62/100], loss:0.09277329314992583
# Epoch [63/100], loss:0.092563292888249
# Epoch [64/100], loss:0.09236574243581
# Epoch [65/100], loss:0.09216704501490755
# Epoch [66/100], loss:0.09197199556353429
# Epoch [67/100], loss:0.09180689051087905
# Epoch [68/100], loss:0.09161889424711889
# Epoch [69/100], loss:0.09146926353506447
# Epoch [70/100], loss:0.09136939094283439
# Epoch [71/100], loss:0.09113795826594677
# Epoch [72/100], loss:0.09099734990528092
# Epoch [73/100], loss:0.0908388207810953
# Epoch [74/100], loss:0.09071352743410713
# Epoch [75/100], loss:0.09058818179308423
# Epoch [76/100], loss:0.09044925830874674
# Epoch [77/100], loss:0.09033980144972162
# Epoch [78/100], loss:0.09022589602901383
# Epoch [79/100], loss:0.0901094198282917
# Epoch [80/100], loss:0.09000033731065585
# Epoch [81/100], loss:0.08990927692943385
# Epoch [82/100], loss:0.08978080141728481
# Epoch [83/100], loss:0.08969959609921749
# Epoch [84/100], loss:0.08959257593567645
# Epoch [85/100], loss:0.0895011915651381
# Epoch [86/100], loss:0.08940448971647191
# Epoch [87/100], loss:0.08932298599052091
# Epoch [88/100], loss:0.08922295520564755
# Epoch [89/100], loss:0.08914889777097369
# Epoch [90/100], loss:0.08905603108015725
# Epoch [91/100], loss:0.08897577940944905
# Epoch [92/100], loss:0.08890023822576065
# Epoch [93/100], loss:0.08884296516687996
# Epoch [94/100], loss:0.08875231801397682
# Epoch [95/100], loss:0.08864783952590685
# Epoch [96/100], loss:0.08855184131231177
# Epoch [97/100], loss:0.08849929586040453
# Epoch [98/100], loss:0.08842804586691608
# Epoch [99/100], loss:0.08832941370407851
# Epoch [100/100], loss:0.08825884023699428

# %%
from matplotlib import pyplot as plt


df_anomaly = optimizator.predict(X_test, y_test)

no_fraud = df_anomaly[(df_anomaly['Class']== 0) & (df_anomaly['Test_Losses'] < 10)]

plt.hist(no_fraud.Test_Losses)
plt.title('Without Fraud')
# Out:
# Text(0.5, 1.0, 'Without Fraud')

# %%
fraud = df_anomaly[(df_anomaly['Class']== 1)]

plt.hist(fraud.Test_Losses)
plt.title('With Fraud')
# Out:
# Text(0.5, 1.0, 'With Fraud')

# %%
from sklearn.metrics import auc, roc_curve


fpr, tpr, thresholds = roc_curve(df_anomaly.Class, df_anomaly.Test_Losses)
roc_auc = auc(fpr, tpr)

plt.title('ROC')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
threshold = 0.5
groups = df_anomaly.groupby('Class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.Test_Losses, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show()

# %%
y_pred = [1 if e > threshold else 0 for e in df_anomaly.Test_Losses.values]
conf_matrix = confusion_matrix(df_anomaly.Class, y_pred)
plt.figure(figsize=(12, 12))

c = ConfusionMatrixDisplay(confusion_matrix = conf_matrix).plot()


plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
